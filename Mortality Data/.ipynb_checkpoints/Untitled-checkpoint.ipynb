# %%
import pandas as pd

# %%
mortality="National_Custom_Data.csv"


mortality_df=pd.read_csv(mortality)
mortality_df.head()
# Out:
#        AREA  SUB AREA AGE GROUP   SEASON  WEEK  THRESHOLD  BASELINE  \
# 0  National       NaN       All  2019-20    40        5.7       5.3
# 1  National       NaN       All  2019-20    41        5.7       5.4
# 2  National       NaN       All  2019-20    42        5.8       5.5
# 3  National       NaN       All  2019-20    43        5.9       5.6
# 4  National       NaN       All  2019-20    44        6.0       5.7
#
#    PERCENT P&I NUM INFLUENZA DEATHS NUM PNEUMONIA DEATHS TOTAL DEATHS  \
# 0          5.2                   16                2,698       52,442
# 1          5.3                   16                2,766       52,850
# 2          5.5                   18                2,976       54,108
# 3          5.6                   30                2,983       53,896
# 4          5.4                   31                2,904       53,953
#
#   PERCENT COMPLETE
# 0           > 100%
# 1           > 100%
# 2           > 100%
# 3           > 100%
# 4           > 100%

# %%
mortality_df2=mortality_df.drop(columns=["SUB AREA", "PERCENT COMPLETE"])
mortality_df2.head(50)
# Out:
#         AREA AGE GROUP   SEASON  WEEK  THRESHOLD  BASELINE  PERCENT P&I  \
# 0   National       All  2019-20    40        5.7       5.3          5.2
# 1   National       All  2019-20    41        5.7       5.4          5.3
# 2   National       All  2019-20    42        5.8       5.5          5.5
# 3   National       All  2019-20    43        5.9       5.6          5.6
# 4   National       All  2019-20    44        6.0       5.7          5.4
# 5   National       All  2019-20    45        6.2       5.8          5.6
# 6   National       All  2019-20    46        6.3       5.9          5.6
# 7   National       All  2019-20    47        6.4       6.0          5.4
# 8   National       All  2019-20    48        6.5       6.2          5.5
# 9   National       All  2019-20    49        6.6       6.3          6.0
# 10  National       All  2019-20    50        6.7       6.4          6.2
# 11  National       All  2019-20    51        6.8       6.5          6.1
# ...
